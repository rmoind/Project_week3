# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import yfinance as yf
import numpy as np

# %%
# Ratings DataFrame + cleaning
df_brands_index = pd.read_csv("ratings.csv")

# Clean the "Overall sustainability rating" column
df_brands_index["Overall sustainability rating"] = df_brands_index["Overall sustainability rating"].apply(lambda x: x.replace("Rated: ", ""))

# Clean the "Planet rating" column
df_brands_index["Planet rating"] = (df_brands_index["Planet rating"].astype(str).str.extract(r"(\d)\s*out of\s*5").astype(float).astype("Int64"))

# Clean the "People rating" column
df_brands_index["People rating"] = (df_brands_index["People rating"].astype(str).str.extract(r"(\d)\s*out of\s*5").astype(float).astype("Int64"))

# Clean the "Animals rating" column
df_brands_index["Animals rating"] = (df_brands_index["Animals rating"].astype(str).str.extract(r"(\d)\s*out of\s*5").astype(float).astype("Int64"))

# Add information about the numerical overall rating
rating_mapping = {"We avoid": 1,
                  "Not good enough": 2,
                  "It's a start": 3,
                  "Good": 4,
                  "Great": 5
                 }
df_brands_index["Overall sustainability rating numerical"] = df_brands_index["Overall sustainability rating"].map(rating_mapping)

# Create a new column with index positions at the Lyst Index 
lyst_rank = {"Miu Miu": 1,
            "Loewe": 2,
            "Saint Laurent": 3,
            "Prada": 4,
            "Coach": 5,
            "The Row": 6,
            "Cos": 7,
            "Chloe": 8,
            "Bottega Veneta": 9,
            "Moncler": 10,
            "Ralph Lauren": 11,
            "Alaia": 12,
            "Balenciaga": 13,
            "Jacquemus": 14,
            "Skims": 15,
            "Versace": 16,
            "Burberry": 17,
            "Gucci": 18,
            "Birkenstock": 19,
            "Valentino": 20
            }
df_brands_index["Lyst position"] = df_brands_index["Brand"].map(lyst_rank)

# Reorder columns
df_brands_index = df_brands_index[['Lyst position','Brand','Overall sustainability rating numerical', 'Overall sustainability rating', 'Planet rating', 'People rating',
       'Animals rating']]

display(df_brands_index)
# Out:
#     Lyst position           Brand  Overall sustainability rating numerical  \
# 0               1         Miu Miu                                        2
# 1               2           Loewe                                        2
# 2               3   Saint Laurent                                        3
# 3               4           Prada                                        3
# 4               5           Coach                                        2
# 5               6         The Row                                        1
# 6               7             Cos                                        3
# 7               8           Chloe                                        3
# 8               9  Bottega Veneta                                        3
# 9              10         Moncler                                        3
# 10             11    Ralph Lauren                                        3
# 11             12           Alaia                                        2
# 12             13      Balenciaga                                        4
# 13             14       Jacquemus                                        2
# 14             15           Skims                                        2
# 15             16         Versace                                        2
# 16             17        Burberry                                        3
# 17             18           Gucci                                        4
# 18             19     Birkenstock                                        2
# 19             20       Valentino                                        2
#
#    Overall sustainability rating  Planet rating  People rating  Animals rating
# 0                Not good enough              3              3               1
# 1                Not good enough              3              2               1
# 2                   It's a start              4              3               2
# 3                   It's a start              3              3               2
# 4                Not good enough              3              2               1
# 5                       We avoid              1              1               2
# 6                   It's a start              3              2               3
# 7                   It's a start              3              3               2
# 8                   It's a start              4              4               2
# 9                   It's a start              4              2               2
# 10                  It's a start              4              3               2
# 11               Not good enough              2              2               2
# 12                          Good              4              4               3
# 13               Not good enough              1              1               2
# 14               Not good enough              1              2            <NA>
# 15               Not good enough              3              2               2
# 16                  It's a start              4              3               2
# 17                          Good              5              4               2
# 18               Not good enough              2              2               2
# 19               Not good enough              2              2               2

# %%
import dataframe_image as dfi

dfi.export(df_brands_index, 'df_brands_index.png', table_conversion='matplotlib')

# %%
# Stocks + Ratings DataFrame + cleaning
df_brands= pd.read_csv("ratings.csv")

# Clean the "Overall sustainability rating" column
df_brands["Overall sustainability rating"] = df_brands["Overall sustainability rating"].apply(lambda x: x.replace("Rated: ", ""))

# Clean the "Planet rating" column
df_brands["Planet rating"] = (df_brands["Planet rating"].astype(str).str.extract(r"(\d)\s*out of\s*5").astype(float).astype("Int64"))

# Clean the "People rating" column
df_brands["People rating"] = (df_brands["People rating"].astype(str).str.extract(r"(\d)\s*out of\s*5").astype(float).astype("Int64"))

# Clean the "Animals rating" column
df_brands["Animals rating"] = (df_brands["Animals rating"].astype(str).str.extract(r"(\d)\s*out of\s*5").astype(float).astype("Int64"))

# Add information about the numerical overall rating
rating_mapping = {"We avoid": 1,
                  "Not good enough": 2,
                  "It's a start": 3,
                  "Good": 4,
                  "Great": 5
                 }
df_brands["Overall sustainability rating numerical"] = df_brands["Overall sustainability rating"].map(rating_mapping)

# Create a new column with index positions at the Lyst Index 
lyst_rank = {"Miu Miu": 1,
            "Loewe": 2,
            "Saint Laurent": 3,
            "Prada": 4,
            "Coach": 5,
            "The Row": 6,
            "Cos": 7,
            "Chloe": 8,
            "Bottega Veneta": 9,
            "Moncler": 10,
            "Ralph Lauren": 11,
            "Alaia": 12,
            "Balenciaga": 13,
            "Jacquemus": 14,
            "Skims": 15,
            "Versace": 16,
            "Burberry": 17,
            "Gucci": 18,
            "Birkenstock": 19,
            "Valentino": 20
            }
df_brands["Lyst position"] = df_brands["Brand"].map(lyst_rank)

# Create a new column with holding company names
holding_company = {"Miu Miu": "Prada Group",
                     "Loewe": "LVMH",
                     "Saint Laurent": "Kering",
                     "Prada": "Prada Group",
                     "Coach": "Tapestry Inc.",
                     "The Row": "Private - Olsen twins",
                     "Cos": "H&M Group",
                     "Chloe": "Richemont",
                     "Bottega Veneta": "Kering",
                     "Moncler": "Moncler S.p.A.",
                     "Ralph Lauren": "Ralph Lauren Corporation",
                     "Alaia": "Richemont",
                     "Balenciaga": "Kering",
                     "Jacquemus": "Private - Simon Porte Jacquemus",
                     "Skims": "Private - Kim Kardashian",
                     "Versace": "Capri Holdings",
                     "Burberry": "Burberry Group plc",
                     "Gucci": "Kering",
                     "Birkenstock": "Private Equity - L Catterton & Financière Agache",  
                     "Valentino": "Private Equity - Mayhoola"
                     }      
df_brands["Holding"] = df_brands["Brand"].map(holding_company)

# Create a new column with information about market exchanges
exchanges = {"Miu Miu": "Hong Kong Stock Exchange",
                     "Loewe": "Euronext Paris",
                     "Saint Laurent": "Euronext Paris",
                     "Prada": "Hong Kong Stock Exchange",
                     "Coach": "NYSE",
                     "The Row": "",
                     "Cos": "Nasdaq Stockholm",
                     "Chloe": "SIX Swiss Exchange",
                     "Bottega Veneta": "Euronext Paris",
                     "Moncler": "Borsa Italiana",
                     "Ralph Lauren": "NYSE",
                     "Alaia": "SIX Swiss Exchange",
                     "Balenciaga": "Euronext Paris",
                     "Jacquemus": "",
                     "Skims": "",
                     "Versace": "NYSE",
                     "Burberry": "London Stock Exchange",
                     "Gucci": "Euronext Paris",
                     "Birkenstock": "NYSE",  
                     "Valentino": ""
                     }      
df_brands["Market exchange"] = df_brands["Brand"].map(exchanges)

# Create a new column with tickers of holding companies
tickers_holding_company = {"Miu Miu": "1913.HK",
                     "Loewe": "MC.PA",
                     "Saint Laurent": "KER.PA",
                     "Prada": "1913.HK",
                     "Coach": "TPR",
                     "The Row": "",
                     "Cos": "HM-B.ST",
                     "Chloe": "CFR.SW",
                     "Bottega Veneta": "KER.PA",
                     "Moncler": "MONC.MI",
                     "Ralph Lauren": "RL",
                     "Alaia": "CFR.SW",
                     "Balenciaga": "KER.PA",
                     "Jacquemus": "",
                     "Skims": "",
                     "Versace": "CPRI",
                     "Burberry": "BRBY.L",
                     "Gucci": "KER.PA",
                     "Birkenstock": "BIRK",  
                     "Valentino": ""
                     }      
df_brands["Ticker holding"] = df_brands["Brand"].map(tickers_holding_company)

# Reorder columns
df_brands = df_brands[['Lyst position','Brand', 'Holding','Market exchange', 'Ticker holding','Overall sustainability rating numerical', 'Overall sustainability rating', 'Planet rating', 'People rating',
       'Animals rating']]

display(df_brands)
# Out:
#     Lyst position           Brand  \
# 0               1         Miu Miu
# 1               2           Loewe
# 2               3   Saint Laurent
# 3               4           Prada
# 4               5           Coach
# 5               6         The Row
# 6               7             Cos
# 7               8           Chloe
# 8               9  Bottega Veneta
# 9              10         Moncler
# 10             11    Ralph Lauren
# 11             12           Alaia
# 12             13      Balenciaga
# 13             14       Jacquemus
# 14             15           Skims
# 15             16         Versace
# 16             17        Burberry
# 17             18           Gucci
# 18             19     Birkenstock
# 19             20       Valentino
#
#                                              Holding  \
# 0                                        Prada Group
# 1                                               LVMH
# 2                                             Kering
# 3                                        Prada Group
# 4                                      Tapestry Inc.
# 5                              Private - Olsen twins
# 6                                          H&M Group
# 7                                          Richemont
# 8                                             Kering
# 9                                     Moncler S.p.A.
# 10                          Ralph Lauren Corporation
# 11                                         Richemont
# 12                                            Kering
# 13                   Private - Simon Porte Jacquemus
# 14                          Private - Kim Kardashian
# 15                                    Capri Holdings
# 16                                Burberry Group plc
# 17                                            Kering
# 18  Private Equity - L Catterton & Financière Agache
# 19                         Private Equity - Mayhoola
#
#              Market exchange Ticker holding  \
# 0   Hong Kong Stock Exchange        1913.HK
# 1             Euronext Paris          MC.PA
# 2             Euronext Paris         KER.PA
# 3   Hong Kong Stock Exchange        1913.HK
# 4                       NYSE            TPR
# 5
# 6           Nasdaq Stockholm        HM-B.ST
# 7         SIX Swiss Exchange         CFR.SW
# 8             Euronext Paris         KER.PA
# 9             Borsa Italiana        MONC.MI
# 10                      NYSE             RL
# 11        SIX Swiss Exchange         CFR.SW
# 12            Euronext Paris         KER.PA
# 13
# 14
# 15                      NYSE           CPRI
# 16     London Stock Exchange         BRBY.L
# 17            Euronext Paris         KER.PA
# 18                      NYSE           BIRK
# 19
#
#     Overall sustainability rating numerical Overall sustainability rating  \
# 0                                         2               Not good enough
# 1                                         2               Not good enough
# 2                                         3                  It's a start
# 3                                         3                  It's a start
# 4                                         2               Not good enough
# 5                                         1                      We avoid
# 6                                         3                  It's a start
# 7                                         3                  It's a start
# 8                                         3                  It's a start
# 9                                         3                  It's a start
# 10                                        3                  It's a start
# 11                                        2               Not good enough
# 12                                        4                          Good
# 13                                        2               Not good enough
# 14                                        2               Not good enough
# 15                                        2               Not good enough
# 16                                        3                  It's a start
# 17                                        4                          Good
# 18                                        2               Not good enough
# 19                                        2               Not good enough
#
#     Planet rating  People rating  Animals rating
# 0               3              3               1
# 1               3              2               1
# 2               4              3               2
# 3               3              3               2
# 4               3              2               1
# 5               1              1               2
# 6               3              2               3
# 7               3              3               2
# 8               4              4               2
# 9               4              2               2
# 10              4              3               2
# 11              2              2               2
# 12              4              4               3
# 13              1              1               2
# 14              1              2            <NA>
# 15              3              2               2
# 16              4              3               2
# 17              5              4               2
# 18              2              2               2
# 19              2              2               2

# %%
import dataframe_image as dfi

dfi.export(df_brands, 'df_brands.png', table_conversion='matplotlib')

# %%
# Create some graphs to visualize the ratings data
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style for the plots
sns.set_style("whitegrid")

# Create a bar plot for the overall sustainability ratings
plt.figure(figsize=(8, 4))
sns.barplot(x='Overall sustainability rating numerical', y='Brand', data=df_brands, palette='viridis')
plt.title('Overall Sustainability Rating by Brand')
plt.xlabel('Rating')
plt.ylabel('Brand')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_28492\4190349045.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Overall sustainability rating numerical', y='Brand', data=df_brands, palette='viridis')

# %%
# Now create a bar plot for the Planet ratings
plt.figure(figsize=(8, 4))
sns.barplot(x='Planet rating', y='Brand', data=df_brands, palette='magma')
plt.title('Planet Rating by Brand')
plt.xlabel('Planet Rating')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_28492\1419460014.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Planet rating', y='Brand', data=df_brands, palette='magma')

# %%
# Now create a bar plot for the People ratings
plt.figure(figsize=(8, 4))
sns.barplot(x='People rating', y='Brand', data=df_brands, palette='magma')
plt.title('People Rating by Brand')
plt.xlabel('People Rating')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_28492\719775815.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='People rating', y='Brand', data=df_brands, palette='magma')

# %%
# Now create a bar plot for the Animals ratings
plt.figure(figsize=(8, 4))
sns.barplot(x='Animals rating', y='Brand', data=df_brands, palette='magma')
plt.title('Animals Rating by Brand')
plt.xlabel('Animals Rating')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_28492\3047470235.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Animals rating', y='Brand', data=df_brands, palette='magma')

# %%
grouped = df_brands.groupby(['Holding', 'Ticker holding'])['Brand'].apply(', '.join).reset_index()
grouped
# Out:
#                                              Holding Ticker holding  \
# 0                                 Burberry Group plc         BRBY.L
# 1                                     Capri Holdings           CPRI
# 2                                          H&M Group        HM-B.ST
# 3                                             Kering         KER.PA
# 4                                               LVMH          MC.PA
# 5                                     Moncler S.p.A.        MONC.MI
# 6                                        Prada Group        1913.HK
# 7                           Private - Kim Kardashian
# 8                              Private - Olsen twins
# 9                    Private - Simon Porte Jacquemus
# 10  Private Equity - L Catterton & Financière Agache           BIRK
# 11                         Private Equity - Mayhoola
# 12                          Ralph Lauren Corporation             RL
# 13                                         Richemont         CFR.SW
# 14                                     Tapestry Inc.            TPR
#
#                                                Brand
# 0                                           Burberry
# 1                                            Versace
# 2                                                Cos
# 3   Saint Laurent, Bottega Veneta, Balenciaga, Gucci
# 4                                              Loewe
# 5                                            Moncler
# 6                                     Miu Miu, Prada
# 7                                              Skims
# 8                                            The Row
# 9                                          Jacquemus
# 10                                       Birkenstock
# 11                                         Valentino
# 12                                      Ralph Lauren
# 13                                      Chloe, Alaia
# 14                                             Coach

# %%
from datetime import timedelta

# Extract tickers
tickers = grouped['Ticker holding'].unique()

# Prepare storage for data
all_data = []

# Loop through tickers and fetch data
for ticker in tickers:
    try:
        # Fetch historical data
        ticker_data = yf.Ticker(ticker).history(period='5y')
        ticker_data['Ticker'] = ticker  # Add a column with the ticker
        
        # Currency information
        info = yf.Ticker(ticker).info
        ticker_data['Currency'] = info.get('currency', 'N/A')  # Add currency information
        
        # Append the data to the list
        all_data.append(ticker_data)
        print(f"Data for {ticker} retrieved successfully.")

    except Exception as e:
        print(f"Failed to retrieve data for {ticker}: {e}")

# Concatenate all data into a single DataFrame
if all_data:
    big_data = pd.concat(all_data)
    big_data.reset_index(inplace=True)  # Reset index to have a flat structure
else:
    big_data = pd.DataFrame()  # Return empty DataFrame if no data
# Out:
# Data for BRBY.L retrieved successfully.
# Data for CPRI retrieved successfully.
# Data for HM-B.ST retrieved successfully.
# Data for KER.PA retrieved successfully.
# Data for MC.PA retrieved successfully.
# Data for MONC.MI retrieved successfully.
# Data for 1913.HK retrieved successfully.
# Failed to retrieve data for : Empty ticker name
# Data for BIRK retrieved successfully.
# Data for RL retrieved successfully.
# Data for CFR.SW retrieved successfully.
# Data for TPR retrieved successfully.

# %%
big_data
# Out:
#                             Date         Open         High          Low  \
# 0      2020-10-23 00:00:00+01:00  1476.030052  1500.996731  1471.536050
# 1      2020-10-26 00:00:00+00:00  1457.055300  1508.486656  1411.446130
# 2      2020-10-27 00:00:00+00:00  1417.108629  1419.605297  1383.653281
# 3      2020-10-28 00:00:00+00:00  1382.155417  1398.633426  1334.219391
# 4      2020-10-29 00:00:00+00:00  1360.683901  1382.654577  1346.702562
# ...                          ...          ...          ...          ...
# 13120  2025-10-16 00:00:00-04:00   117.430000   118.379997   115.680000
# 13121  2025-10-17 00:00:00-04:00   115.669998   117.300003   115.099998
# 13122  2025-10-20 00:00:00-04:00   117.639999   117.750000   115.830002
# 13123  2025-10-21 00:00:00-04:00   117.870003   117.949997   116.000000
# 13124  2025-10-22 00:00:00-04:00   117.190002   118.449997   114.190002
#
#              Close   Volume  Dividends  Stock Splits  Ticker Currency
# 0      1486.016724  2147270        0.0           0.0  BRBY.L      GBp
# 1      1413.613281  1346998        0.0           0.0  BRBY.L      GBp
# 2      1406.123291   956763        0.0           0.0  BRBY.L      GBp
# 3      1361.682739  1160195        0.0           0.0  BRBY.L      GBp
# 4      1366.675903  1160050        0.0           0.0  BRBY.L      GBp
# ...            ...      ...        ...           ...     ...      ...
# 13120   116.510002  1432100        0.0           0.0     TPR      USD
# 13121   116.820000  1908500        0.0           0.0     TPR      USD
# 13122   116.339996  1442300        0.0           0.0     TPR      USD
# 13123   117.139999  2091700        0.0           0.0     TPR      USD
# 13124   115.330002  2461300        0.0           0.0     TPR      USD
#
# [13125 rows x 10 columns]

# %%
# Create a graph with evolution of stock prices per ticker

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
plt.figure(figsize=(12, 6))
for ticker in tickers:
    ticker_data = big_data[big_data['Ticker'] == ticker]
    plt.plot(ticker_data['Date'], ticker_data['Close'], label=ticker)

plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Stock Prices Evolution')
plt.legend()
plt.grid()
plt.show()

# %%
big_data = big_data.drop(['High', 'Low', 'Volume', 'Dividends',
       'Stock Splits'], axis=1)

big_data
# Out:
#                             Date         Open        Close  Ticker Currency
# 0      2020-10-23 00:00:00+01:00  1476.030052  1486.016724  BRBY.L      GBp
# 1      2020-10-26 00:00:00+00:00  1457.055300  1413.613281  BRBY.L      GBp
# 2      2020-10-27 00:00:00+00:00  1417.108629  1406.123291  BRBY.L      GBp
# 3      2020-10-28 00:00:00+00:00  1382.155417  1361.682739  BRBY.L      GBp
# 4      2020-10-29 00:00:00+00:00  1360.683901  1366.675903  BRBY.L      GBp
# ...                          ...          ...          ...     ...      ...
# 13120  2025-10-16 00:00:00-04:00   117.430000   116.510002     TPR      USD
# 13121  2025-10-17 00:00:00-04:00   115.669998   116.820000     TPR      USD
# 13122  2025-10-20 00:00:00-04:00   117.639999   116.339996     TPR      USD
# 13123  2025-10-21 00:00:00-04:00   117.870003   117.139999     TPR      USD
# 13124  2025-10-22 00:00:00-04:00   117.190002   115.330002     TPR      USD
#
# [13125 rows x 5 columns]

# %%
# Ensure the 'Date' column is in datetime format
big_data['Date'] = pd.to_datetime(big_data['Date'], utc=True)

# Extract day, month, and year and create a new column in your desired format
big_data['day-month-year'] = big_data['Date'].dt.strftime('%d-%m-%Y')

specific_dates = ['22-10-2020', '22-10-2025']

# Filter the rows where 'day-month-year' matches any of the specific dates
filtered_data = big_data.loc[big_data['day-month-year'].isin(specific_dates)]

filtered_data = filtered_data.drop(['Date'], axis=1)

# %%
filtered_data
# Out:
#               Open        Close   Ticker Currency day-month-year
# 0      1476.030052  1486.016724   BRBY.L      GBp     22-10-2020
# 1261   1264.500000  1284.000000   BRBY.L      GBp     22-10-2025
# 2516     22.320000    22.440001     CPRI      USD     22-10-2025
# 2517    129.406197   129.201828  HM-B.ST      SEK     22-10-2020
# 3775    179.000000   180.100006  HM-B.ST      SEK     22-10-2025
# 3776    488.969760   487.566711   KER.PA      EUR     22-10-2020
# 5058    332.500000   352.649994   KER.PA      EUR     22-10-2025
# 5059    390.161555   394.028198    MC.PA      EUR     22-10-2020
# 6341    622.299988   625.599976    MC.PA      EUR     22-10-2025
# 6342     34.837913    35.917084  MONC.MI      EUR     22-10-2020
# 7614     52.160000    53.240002  MONC.MI      EUR     22-10-2025
# 7615     30.381690    30.749954  1913.HK      HKD     22-10-2020
# 8844     46.660000    46.299999  1913.HK      HKD     22-10-2025
# 9354     42.660000    42.990002     BIRK      USD     22-10-2025
# 10609   334.209991   332.119995       RL      USD     22-10-2025
# 10610    55.140493    55.475105   CFR.SW      CHF     22-10-2020
# 11869   161.199997   161.500000   CFR.SW      CHF     22-10-2025
# 13124   117.190002   115.330002      TPR      USD     22-10-2025

# %%
pivot_data = filtered_data.pivot_table(index='Ticker', columns='day-month-year', values=['Close'])
pivot_data

# BIRK has no data for 22-10-2020, first observation is 11-10-2023 with a value of 41
# So we're going to fill manually
pivot_data.loc['BIRK', ('Close', '22-10-2020')] = 41.00

# CPRI, RL and TPR do have data for 22-10-2020, but it's not showed in the dataset
# So we're going to fill manually
pivot_data.loc['CPRI', ('Close', '22-10-2020')] = 22.56
pivot_data.loc['RL', ('Close', '22-10-2020')] = 77.11
pivot_data.loc['TPR', ('Close', '22-10-2020')] = 21.85

# %%
pivot_data['Performance_%'] = (
    (pivot_data[('Close', '22-10-2025')] / pivot_data[('Close', '22-10-2020')] - 1) * 100
).round(2)

pivot_data
# Out:
#                       Close              Performance_%
# day-month-year   22-10-2020   22-10-2025
# Ticker
# 1913.HK           30.749954    46.299999         50.57
# BIRK              41.000000    42.990002          4.85
# BRBY.L          1486.016724  1284.000000        -13.59
# CFR.SW            55.475105   161.500000        191.12
# CPRI              22.560000    22.440001         -0.53
# HM-B.ST          129.201828   180.100006         39.39
# KER.PA           487.566711   352.649994        -27.67
# MC.PA            394.028198   625.599976         58.77
# MONC.MI           35.917084    53.240002         48.23
# RL                77.110000   332.119995        330.71
# TPR               21.850000   115.330002        427.83

# %%
# Present the performance data in a graph
plt.figure(figsize=(8, 4))
sns.barplot(x='Performance_%', y='Ticker', data=pivot_data, palette='viridis')
plt.title('Stock Performance from 22-10-2020 to 22-10-2025')
plt.xlabel('Performance (%)')
plt.ylabel('Ticker')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13132\1721180532.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Performance_%', y='Ticker', data=pivot_data, palette='viridis')
